# %%
import mysql.connector
import pandas as pd

# %%
def create_database():
    conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="germanshepherd",
        autocommit=True
    )
    cur = conn.cursor()

    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")
    
    # Close the connection for the default database
    conn.close()

    conn = mysql.connector.connect(
        host="localhost",
        database="accounts",
        user="root",
        password="germanshepherd"
    )
    cur = conn.cursor()

    return cur, conn

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv('C:\\Users\\Amisha\\Downloads\\Wealth-AccountsCountry.csv')

# %%
AccountsCountry.head()
# Out:
#   Country Code                  Long Name         Income Group  \
# 0          ALB        Republic of Albania  Upper middle income
# 1          ARG         Argentine Republic  Upper middle income
# 2          ARM        Republic of Armenia  Upper middle income
# 3          AUS  Commonwealth of Australia          High income
# 4          AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# ...

# %%
AccountsCountry_clean = AccountsCountry[['Country Code','Short Name','Table Name','Long Name','Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
#   Country Code Short Name Table Name                  Long Name  \
# 0          ALB    Albania    Albania        Republic of Albania
# 1          ARG  Argentina  Argentina         Argentine Republic
# 2          ARM    Armenia    Armenia        Republic of Armenia
# 3          AUS  Australia  Australia  Commonwealth of Australia
# 4          AUT    Austria    Austria        Republic of Austria
#
#        Currency Unit
# 0       Albanian lek
# 1     Argentine peso
# 2      Armenian dram
# 3  Australian dollar
# 4               Euro

# %%
AccountsData = pd.read_csv("C:\\Users\\Amisha\\Downloads\\Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsData_clean = AccountsData[['Country Name','Country Code','Series Name','Series Code','1995 [YR1995]','2000 [YR2000]','2005 [YR2005]','2010 [YR2010]','2015 [YR2015]']]

# %%
AccountsData_clean.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 2000 [YR2000]  2005 [YR2005]  2010 [YR2010]  2015 [YR2015]
# 0      4.49E+10      4.36E+10   5.440000e+10   6.810000e+10   7.370000e+10
# 1      14072.79      14118.13   1.807230e+04   2.336286e+04   2.559371e+04
# 2      3468.858      3424.007   2.222115e+03   2.889150e+03   2.987545e+03
# ...

# %%
AccountsSeries = pd.read_csv("C:\\Users\\Amisha\\Downloads\\Wealth-AccountSeries.csv")

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries = AccountsSeries[['Code', 'Topic', 'Indicator Name']]

# %%
AccountsSeries.head()
# Out:
#              Code          Topic  \
# 0       NW.HCA.TO  Human capital
# 1       NW.HCA.PC  Human capital
# 2  NW.HCA.FEMP.PC  Human capital
# 3  NW.HCA.MEMP.PC  Human capital
# 4  NW.HCA.FEMA.PC  Human capital
#
#                                       Indicator Name
# 0                  Human capital (constant 2018 US$)
# 1       Human capital per capita (constant 2018 US$)
# 2  Human capital per capita, employed female (con...
# 3  Human capital per capita, employed male (const...
# 4  Human capital per capita, female (constant 201...

# %%
cur, conn = create_database()

# %%
accounts_country_table_create = ("""
    CREATE TABLE IF NOT EXISTS accountscountry (
        country_code VARCHAR(255) PRIMARY KEY,
        short_name VARCHAR(255),
        table_name VARCHAR(255),
        long_name VARCHAR(255),
        currency_unit VARCHAR(255)
    )
""")
cur.execute(accounts_country_table_create)
conn.commit()

# %%
accounts_data_table_create = ("""
    CREATE TABLE IF NOT EXISTS accountsdata (
        country_name VARCHAR(255),
        country_code VARCHAR(10),
        series_name VARCHAR(255),
        series_code VARCHAR(50),
        year_1995 DECIMAL(30, 2),
        year_2000 DECIMAL(30, 2),
        year_2005 DECIMAL(30, 2),
        year_2010 DECIMAL(30, 2),
        year_2015 DECIMAL(30, 2)
    )
""")

cur.execute(accounts_data_table_create)
conn.commit()

# %%
alter_precision_query = """
    ALTER TABLE accountsdata
    MODIFY COLUMN year_1995 DECIMAL(30, 2),
    MODIFY COLUMN year_2000 DECIMAL(30, 2),
    MODIFY COLUMN year_2005 DECIMAL(30, 2),
    MODIFY COLUMN year_2010 DECIMAL(30, 2),
    MODIFY COLUMN year_2015 DECIMAL(30, 2);
"""

# %%
accounts_series_table_create = """
    CREATE TABLE IF NOT EXISTS accountseries (
        series_code VARCHAR(255),
        topic VARCHAR(255),
        indicator_name VARCHAR(255)
    )
"""

cur.execute(accounts_series_table_create)
conn.commit()

# %%
accounts_country_table_insert = ("""
    INSERT INTO accountscountry (
        country_code,
        short_name,
        table_name,
        long_name,
        currency_unit
    )
    VALUES (%s, %s, %s, %s, %s)
    ON DUPLICATE KEY UPDATE
        short_name = VALUES(short_name),
        table_name = VALUES(table_name),
        long_name = VALUES(long_name),
        currency_unit = VALUES(currency_unit)
""")

for i, row in AccountsCountry_clean.iterrows():
    if pd.notna(row['Country Code']):
        row_values = [value if pd.notna(value) else None for value in row]
        cur.execute(accounts_country_table_insert, row_values)
    
conn.commit()

# %%
accounts_data_table_insert = ("""
    INSERT INTO accountsdata (
        country_name,
        country_code,
        series_name,
        series_code,
        year_1995,
        year_2000,
        year_2005,
        year_2010,
        year_2015
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
""")

for i, row in AccountsData.iterrows():
    row_values = [value if pd.notna(value) else None for value in row]
    cur.execute(accounts_data_table_insert, row_values)

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [24], line 18
#      16 for i, row in AccountsData.iterrows():
#      17     row_values = [value if pd.notna(value) else None for value in row]
# ---> 18     cur.execute(accounts_data_table_insert, row_values)
#      20 conn.commit()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:271, in CMySQLCursor.execute(self, operation, params, multi)
#     269         stmt = RE_PY_PARAM.sub(psub, stmt)
#     270         if psub.remaining != 0:
# --> 271             raise ProgrammingError(
#     272                 "Not all parameters were used in the SQL statement"
#     273             )
#     275 try:
#     276     result = self._cnx.cmd_query(
#     277         stmt,
#     278         raw=self._raw,
#     279         buffered=self._buffered,
# ...

# %%
account_series_table_insert = ("""INSERT INTO accountseries(
series_code,
topic,
indicator_name)
VALUES (%s, %s, %s)
""")

for i, row in AccountsSeries.iterrows():
        cur.execute(account_series_table_insert, list(row))
conn.commit()
